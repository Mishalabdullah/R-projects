# %% [markdown]
# our goal is to find the factors in which the price of a metal depends

# %% [markdown]
# First we load tidyverse and install the dataset after that we will view the whole data set and also its summary.

# %%
library(tidyverse)
data("diamonds")
summary(diamonds)
# Out:
#      carat               cut        color        clarity          depth
#  Min.   :0.2000   Fair     : 1610   D: 6775   SI1    :13065   Min.   :43.00
#  1st Qu.:0.4000   Good     : 4906   E: 9797   VS2    :12258   1st Qu.:61.00
#  Median :0.7000   Very Good:12082   F: 9542   SI2    : 9194   Median :61.80
#  Mean   :0.7979   Premium  :13791   G:11292   VS1    : 8171   Mean   :61.75
#  3rd Qu.:1.0400   Ideal    :21551   H: 8304   VVS2   : 5066   3rd Qu.:62.50
#  Max.   :5.0100                     I: 5422   VVS1   : 3655   Max.   :79.00
#                                     J: 2808   (Other): 2531
#      table           price             x                y
#  Min.   :43.00   Min.   :  326   Min.   : 0.000   Min.   : 0.000
#  1st Qu.:56.00   1st Qu.:  950   1st Qu.: 4.710   1st Qu.: 4.720
#  Median :57.00   Median : 2401   Median : 5.700   Median : 5.710
#  Mean   :57.46   Mean   : 3933   Mean   : 5.731   Mean   : 5.735
#  3rd Qu.:59.00   3rd Qu.: 5324   3rd Qu.: 6.540   3rd Qu.: 6.540
# ...

# %%
View(diamonds)
# Out:
#       carat cut       color clarity depth table price x    y    z
# 1     0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43
# 2     0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31
# 3     0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31
# 4     0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63
# 5     0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75
# 6     0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48
# 7     0.24  Very Good I     VVS1    62.3  57    336   3.95 3.98 2.47
# 8     0.26  Very Good H     SI1     61.9  55    337   4.07 4.11 2.53
# 9     0.22  Fair      E     VS2     65.1  61    337   3.87 3.78 2.49
# 10    0.23  Very Good H     VS1     59.4  61    338   4.00 4.05 2.39
# 11    0.30  Good      J     SI1     64.0  55    339   4.25 4.28 2.73
# 12    0.23  Ideal     J     VS1     62.8  56    340   3.93 3.90 2.46
# 13    0.22  Premium   F     SI1     60.4  61    342   3.88 3.84 2.33
# ...

# %% [markdown]
# After this now we need to create a preview for this data.

# %%
head(diamonds)
# Out:
#   carat cut       color clarity depth table price x    y    z
# 1 0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43
# 2 0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31
# 3 0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31
# 4 0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63
# 5 0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75
# 6 0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48

# %% [markdown]
# now we will add a new column to the data set which contain the information about the carat of the diamonds, we will name it carat_2 and will multiply the value for the ease o calcualion.

# %%
mutate(diamonds, carat_2=carat*100)
# Out:
#       carat cut       color clarity depth table price x    y    z    carat_2
# 1     0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43 23
# 2     0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31 21
# 3     0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31 23
# 4     0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63 29
# 5     0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75 31
# 6     0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48 24
# 7     0.24  Very Good I     VVS1    62.3  57    336   3.95 3.98 2.47 24
# 8     0.26  Very Good H     SI1     61.9  55    337   4.07 4.11 2.53 26
# 9     0.22  Fair      E     VS2     65.1  61    337   3.87 3.78 2.49 22
# 10    0.23  Very Good H     VS1     59.4  61    338   4.00 4.05 2.39 23
# 11    0.30  Good      J     SI1     64.0  55    339   4.25 4.28 2.73 30
# 12    0.23  Ideal     J     VS1     62.8  56    340   3.93 3.90 2.46 23
# ...

# %% [markdown]
# Now we can install data cleaning packages like here, janitor and skimr and also load them we also need to install dplyr package also.

# %%
install.packages("here")
install.packages("skimr")
install.packages("janitor")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘snakecase’

# %%
library("here")
library("skimr")
library("janitor")
install.packages("dplyr")
library("dplyr")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library("dplyr")

# %%
install.packages("diamonds")
library("ggplot2")
library("diamonds")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message:
# “package ‘diamonds’ is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages”
# Error in library("diamonds"): there is no package called ‘diamonds’
# Traceback:
#
# 1. library("diamonds")

# %% [markdown]
# as it is the next day and we are using google colab as the coding platform we need to load our packages after a long interval

# %%
library("tidyverse")
library("ggplot2")
library("dplyr")

# %%
ggplot(data=diamonds)+geom_bar(mapping=aes(x=color,fill=cut))+ facet_wrap(~cut)
# Out:
# plot without title

# %%
library("tidyverse")
library("ggplot2")
library("dplyr")
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.3     ✔ purrr   0.3.4
# ✔ tibble  3.1.2     ✔ dplyr   1.0.6
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
ggplot(data=diamonds)+geom_bar(mapping=aes(x=carat,fill=cut))+ facet_wrap(~cut)
# Out:
# plot without title

# %%
ggplot(data=diamonds)+geom_bar(mapping=aes(x=clarity,fill=cut))+ facet_wrap(~cut)
# Out:
# plot without title

# %%
ggplot(data=diamonds)+geom_bar(mapping=aes(x=depth,fill=cut))+ facet_wrap(~cut)
# Out:
# plot without title

# %% [markdown]
# This shows that the price of the metal depends upon the depth,clarity and carat.
